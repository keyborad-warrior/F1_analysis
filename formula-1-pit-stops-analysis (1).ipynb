# %% [markdown]
# # Background
#
# What I love about Formula 1 and its place in sports, is the attention all the teams pay to every ounce of performance it can gain on and off the track. It's pursuit of continuous improvement is truly admirable. On that note, I was very interested in the data on their pit stops and how it might provide some insights to parts of the sport I had not considered before.
#
# Since the beginning of Formula 1, the pit stop has been an iconic part of the race format. At the beginning of the sport, the time spent in the pit lane made up a significant portion of the race. Being the optimizers these teams were, the time spent in the pit played a key part of shaving meaningful time off a team's race ultimately translating into success on the track. Technologies were developed and processes evaluated to minimize pit times, and rules changed over time to adapt to both performance and safety developments.
#
# Technologies have gotten to a point where cars no longer need to be pitted to refuel or change tyres; however, the pit stop is a mainstay in the sport and adds an element of uncertainty and strategies making the sport all the more exciting for us the spectators. This notebook will explore the pit stop data and shed some light on how important the pit stop is in a race and what does it mean to have a "good" pit stop.

# %% [markdown]
# # Objective
#
# This notebook will explore F1 pit stop data and gain a better understanding of how the pit stop plays its role in the F1 Grand Prix. Using the findings, I will attempt to answer the questions below which will hopefully yield some new perspectives on the sport!
#
# ## Questions I want to answer:
# * How did pit stop durations change over time?
# * Is there a relationship between pit stop durations and constructor?
# * Is there a relationship between pit stop durations and race circuit?
# * What is the time spent in the pit lane as a percentage of the race?
# * Who is the best constructor on pit stop performance?
#
# Without any further ado, let's go!

# %% [markdown]
# <div style="width:100%; text-align:center"><img style="align:middle; width:100%" src="https://c.tenor.com/tg28WEO2hLoAAAAC/f1-pitstop.gif"></div>

# %% [markdown]
# # Setup
#
# The usual boring stuff but necessary stuff to get all set up. Importing libraries, reading in data, and cleaning it up. You know the drill.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

import os
fnames = []
fpaths = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        fnames.append(filename.split('.')[0])
        fpaths.append(os.path.join(dirname, filename))
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/formula-1-world-championship-1950-2020/races.csv
# /kaggle/input/formula-1-world-championship-1950-2020/constructor_results.csv
# /kaggle/input/formula-1-world-championship-1950-2020/drivers.csv
# /kaggle/input/formula-1-world-championship-1950-2020/constructors.csv
# /kaggle/input/formula-1-world-championship-1950-2020/lap_times.csv
# /kaggle/input/formula-1-world-championship-1950-2020/status.csv
# /kaggle/input/formula-1-world-championship-1950-2020/driver_standings.csv
# /kaggle/input/formula-1-world-championship-1950-2020/seasons.csv
# /kaggle/input/formula-1-world-championship-1950-2020/pit_stops.csv
# /kaggle/input/formula-1-world-championship-1950-2020/sprint_results.csv
# /kaggle/input/formula-1-world-championship-1950-2020/constructor_standings.csv
# /kaggle/input/formula-1-world-championship-1950-2020/results.csv
# /kaggle/input/formula-1-world-championship-1950-2020/circuits.csv
# /kaggle/input/formula-1-world-championship-1950-2020/qualifying.csv

# %% [markdown]
# ## Reading the data

# %%
# Read data
fpath = '/kaggle/input/formula-1-world-championship-1950-2020/'
circuits = pd.read_csv(f'{fpath}circuits.csv', index_col=0, na_values=r'\N')
constructorResults = pd.read_csv(f'{fpath}constructor_results.csv', index_col=0, na_values=r'\N')
constructors = pd.read_csv(f'{fpath}constructors.csv', index_col=0, na_values=r'\N')
constructorStandings = pd.read_csv(f'{fpath}constructor_standings.csv', index_col=0, na_values=r'\N')
drivers = pd.read_csv(f'{fpath}drivers.csv', index_col=0, na_values=r'\N')
driverStandings = pd.read_csv(f'{fpath}driver_standings.csv', index_col=0, na_values=r'\N')
lapTimes = pd.read_csv(f'{fpath}lap_times.csv')
pitStops = pd.read_csv(f'{fpath}pit_stops.csv')
qualifying = pd.read_csv(f'{fpath}qualifying.csv', index_col=0, na_values=r'\N')
races = pd.read_csv(f'{fpath}races.csv', na_values=r'\N')
results = pd.read_csv(f'{fpath}results.csv', index_col=0, na_values=r'\N')
seasons = pd.read_csv(f'{fpath}seasons.csv', index_col=0, na_values=r'\N')
status = pd.read_csv(f'{fpath}status.csv', index_col=0, na_values=r'\N')

# Post-reading formatting 
circuits = circuits.rename(columns={'name':'circuitName','location':'circuitLocation','country':'circuitCountry','url':'circuitUrl'})
drivers = drivers.rename(columns={'nationality':'driverNationality','url':'driverUrl'})
drivers['driverName'] = drivers['forename']+' '+drivers['surname']
constructors = constructors.rename(columns={'name':'constructorName','nationality':'constructorNationality','url':'constructorUrl'})
races.index = races.index.set_names(['raceId','year','round','circuitId','raceName','date','time','raceUrl','a','b'])
races = races[[]].reset_index()[['raceId','year','round','circuitId','raceName','date','time','raceUrl']]
races.set_index('raceId',inplace=True)
races['date'] = races['date'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d'))
pitStops = pitStops.rename(columns={'time':'pitTime'})
pitStops['seconds'] = pitStops['milliseconds'].apply(lambda x: x/1000)
results['seconds'] = results['milliseconds'].apply(lambda x: x/1000)

# %%
# Constructor color mapping
constructor_color_map = {
    'Toro Rosso':'#0000FF',
    'Mercedes':'#6CD3BF',
    'Red Bull':'#1E5BC6',
    'Ferrari':'#ED1C24',
    'Williams':'#37BEDD',
    'Force India':'#FF80C7',
    'Virgin':'#c82e37',
    'Renault':'#FFD800',
    'McLaren':'#F58020',
    'Sauber':'#006EFF',
    'Lotus':'#FFB800',
    'HRT':'#b2945e',
    'Caterham':'#0b361f',
    'Lotus F1':'#FFB800',
    'Marussia':'#6E0000',
    'Manor Marussia':'#6E0000',
    'Haas F1 Team':'#B6BABD',
    'Racing Point':'#F596C8',
    'Aston Martin':'#2D826D',
    'Alfa Romeo':'#B12039',
    'AlphaTauri':'#4E7C9B',
    'Alpine F1 Team':'#2293D1'
}

# %% [markdown]
# # Pit Stop Data
#
# <b>Note:</b> In the context of the data I'm using, pit stop durations include the total time in the pit lane and not only when the car is stationary.

# %%
pitStops
# Out:
#       raceId  driverId  stop  lap   pitTime duration  milliseconds  seconds
# 0        841       153     1    1  17:05:23   26.898         26898   26.898
# 1        841        30     1    1  17:05:52   25.021         25021   25.021
# 2        841        17     1   11  17:20:48   23.426         23426   23.426
# 3        841         4     1   12  17:22:34   23.251         23251   23.251
# 4        841        13     1   13  17:24:10   23.842         23842   23.842
# ...      ...       ...   ...  ...       ...      ...           ...      ...
# 8882    1074       840     3   45  19:20:32   25.039         25039   25.039
# 8883    1074       846     3   45  19:20:59   24.975         24975   24.975
# 8884    1074       849     3   45  19:21:07   24.658         24658   24.658
# 8885    1074       825     3   46  19:21:29   26.051         26051   26.051
# 8886    1074       848     3   46  19:22:54   25.055         25055   25.055
#
# [8887 rows x 8 columns]

# %%
pitStops.describe().T
# Out:
#                count          mean            std        min         25%  \
# raceId        8887.0    945.217621      69.807472    841.000    882.0000
# driverId      8887.0    495.260380     394.115984      1.000     17.0000
# stop          8887.0      1.769664       0.922955      1.000      1.0000
# lap           8887.0     25.152357      14.496368      1.000     13.0000
# milliseconds  8887.0  67550.097108  248002.120977  12897.000  21915.5000
# seconds       8887.0     67.550097     248.002121     12.897     21.9155
#
#                     50%        75%          max
# raceId          943.000   1004.000     1074.000
# driverId        814.000    828.000      855.000
# stop              2.000      2.000        6.000
# lap              25.000     36.000       78.000
# milliseconds  23546.000  26099.000  2077164.000
# seconds          23.546     26.099     2077.164

# %%
newResults = pd.merge(results,races,left_on='raceId',right_index=True,how='left')
newResults = pd.merge(newResults,circuits,left_on='circuitId',right_index=True,how='left')
newResults = pd.merge(newResults,constructors,left_on='constructorId',right_index=True,how='left')
newResults = pd.merge(newResults,drivers,left_on='driverId',right_index=True,how='left')
newResults
# Out:
#           raceId  driverId  constructorId  number_x  grid  position  \
# resultId
# 1             18         1              1      22.0     1       1.0
# 2             18         2              2       3.0     5       2.0
# 3             18         3              3       7.0     7       3.0
# 4             18         4              4       5.0    11       4.0
# 5             18         5              1      23.0     3       5.0
# ...          ...       ...            ...       ...   ...       ...
# 25421       1074       849              3       6.0    20      16.0
# 25422       1074       807            117      27.0    17      17.0
# 25423       1074       815              9      11.0     4      18.0
# 25424       1074       830              9       1.0     2      19.0
# 25425       1074       842            213      10.0    10       NaN
#
#          positionText  positionOrder  points  laps  ...  \
# resultId                                            ...
# 1                   1              1    10.0    58  ...
# 2                   2              2     8.0    58  ...
# 3                   3              3     6.0    58  ...
# 4                   4              4     5.0    58  ...
# 5                   5              5     4.0    58  ...
# ...               ...            ...     ...   ...  ...
# 25421              16             16     0.0    57  ...
# 25422              17             17     0.0    57  ...
# 25423              18             18     0.0    56  ...
# 25424              19             19     0.0    54  ...
# 25425               R             20     0.0    44  ...
#
#                                              constructorUrl       driverRef  \
# resultId
# 1                      http://en.wikipedia.org/wiki/McLaren        hamilton
# 2                   http://en.wikipedia.org/wiki/BMW_Sauber        heidfeld
# 3         http://en.wikipedia.org/wiki/Williams_Grand_Pr...         rosberg
# 4         http://en.wikipedia.org/wiki/Renault_in_Formul...          alonso
# 5                      http://en.wikipedia.org/wiki/McLaren      kovalainen
# ...                                                     ...             ...
# 25421     http://en.wikipedia.org/wiki/Williams_Grand_Pr...          latifi
# 25422     http://en.wikipedia.org/wiki/Aston_Martin_in_F...      hulkenberg
# 25423          http://en.wikipedia.org/wiki/Red_Bull_Racing           perez
# 25424          http://en.wikipedia.org/wiki/Red_Bull_Racing  max_verstappen
# 25425      http://en.wikipedia.org/wiki/Scuderia_AlphaTauri           gasly
#
#           number_y  code  forename     surname         dob  driverNationality  \
# resultId
# 1             44.0   HAM     Lewis    Hamilton  1985-01-07            British
# 2              NaN   HEI      Nick    Heidfeld  1977-05-10             German
# 3              6.0   ROS      Nico     Rosberg  1985-06-27             German
# 4             14.0   ALO  Fernando      Alonso  1981-07-29            Spanish
# 5              NaN   KOV    Heikki  Kovalainen  1981-10-19            Finnish
# ...            ...   ...       ...         ...         ...                ...
# 25421          6.0   LAT  Nicholas      Latifi  1995-06-29           Canadian
# 25422         27.0   HUL      Nico  Hülkenberg  1987-08-19             German
# 25423         11.0   PER    Sergio       Pérez  1990-01-26            Mexican
# 25424         33.0   VER       Max  Verstappen  1997-09-30              Dutch
# 25425         10.0   GAS    Pierre       Gasly  1996-02-07             French
#
#                                                   driverUrl         driverName
# resultId
# 1               http://en.wikipedia.org/wiki/Lewis_Hamilton     Lewis Hamilton
# 2                http://en.wikipedia.org/wiki/Nick_Heidfeld      Nick Heidfeld
# 3                 http://en.wikipedia.org/wiki/Nico_Rosberg       Nico Rosberg
# 4              http://en.wikipedia.org/wiki/Fernando_Alonso    Fernando Alonso
# 5            http://en.wikipedia.org/wiki/Heikki_Kovalainen  Heikki Kovalainen
# ...                                                     ...                ...
# 25421          http://en.wikipedia.org/wiki/Nicholas_Latifi    Nicholas Latifi
# 25422     http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg    Nico Hülkenberg
# 25423        http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez       Sergio Pérez
# 25424           http://en.wikipedia.org/wiki/Max_Verstappen     Max Verstappen
# 25425             http://en.wikipedia.org/wiki/Pierre_Gasly       Pierre Gasly
#
# [25420 rows x 46 columns]

# %%
newPitStops = pd.merge(pitStops,races,left_on='raceId',right_index=True,how='left')
newPitStops = pd.merge(newPitStops,circuits,left_on='circuitId',right_index=True,how='left')
newPitStops = pd.merge(newPitStops,newResults[['raceId','driverId','driverName','constructorId','constructorName']],left_on=['raceId','driverId'],right_on=['raceId','driverId'])
newPitStops
# Out:
#       raceId  driverId  stop  lap   pitTime duration  milliseconds  seconds  \
# 0        841       153     1    1  17:05:23   26.898         26898   26.898
# 1        841       153     2   17  17:31:06   24.463         24463   24.463
# 2        841       153     3   35  17:59:45   26.348         26348   26.348
# 3        841        30     1    1  17:05:52   25.021         25021   25.021
# 4        841        30     2   17  17:32:08   23.988         23988   23.988
# ...      ...       ...   ...  ...       ...      ...           ...      ...
# 8882    1074       807     2   37  19:06:47   26.712         26712   26.712
# 8883    1074       807     3   44  19:18:58   25.748         25748   25.748
# 8884    1074       846     1   24  18:44:41   24.568         24568   24.568
# 8885    1074       846     2   41  19:13:23   27.367         27367   27.367
# 8886    1074       846     3   45  19:20:59   24.975         24975   24.975
#
#       year  round  ...                     circuitName circuitLocation  \
# 0     2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 1     2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 2     2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 3     2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 4     2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# ...    ...    ...  ...                             ...             ...
# 8882  2022      1  ...   Bahrain International Circuit          Sakhir
# 8883  2022      1  ...   Bahrain International Circuit          Sakhir
# 8884  2022      1  ...   Bahrain International Circuit          Sakhir
# 8885  2022      1  ...   Bahrain International Circuit          Sakhir
# 8886  2022      1  ...   Bahrain International Circuit          Sakhir
#
#      circuitCountry      lat       lng   alt  \
# 0         Australia -37.8497  144.9680  10.0
# 1         Australia -37.8497  144.9680  10.0
# 2         Australia -37.8497  144.9680  10.0
# 3         Australia -37.8497  144.9680  10.0
# 4         Australia -37.8497  144.9680  10.0
# ...             ...      ...       ...   ...
# 8882        Bahrain  26.0325   50.5106   7.0
# 8883        Bahrain  26.0325   50.5106   7.0
# 8884        Bahrain  26.0325   50.5106   7.0
# 8885        Bahrain  26.0325   50.5106   7.0
# 8886        Bahrain  26.0325   50.5106   7.0
#
#                                              circuitUrl          driverName  \
# 0     http://en.wikipedia.org/wiki/Melbourne_Grand_P...   Jaime Alguersuari
# 1     http://en.wikipedia.org/wiki/Melbourne_Grand_P...   Jaime Alguersuari
# 2     http://en.wikipedia.org/wiki/Melbourne_Grand_P...   Jaime Alguersuari
# 3     http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Michael Schumacher
# 4     http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Michael Schumacher
# ...                                                 ...                 ...
# 8882  http://en.wikipedia.org/wiki/Bahrain_Internati...     Nico Hülkenberg
# 8883  http://en.wikipedia.org/wiki/Bahrain_Internati...     Nico Hülkenberg
# 8884  http://en.wikipedia.org/wiki/Bahrain_Internati...        Lando Norris
# 8885  http://en.wikipedia.org/wiki/Bahrain_Internati...        Lando Norris
# 8886  http://en.wikipedia.org/wiki/Bahrain_Internati...        Lando Norris
#
#      constructorId  constructorName
# 0                5       Toro Rosso
# 1                5       Toro Rosso
# 2                5       Toro Rosso
# 3              131         Mercedes
# 4              131         Mercedes
# ...            ...              ...
# 8882           117     Aston Martin
# 8883           117     Aston Martin
# 8884             1          McLaren
# 8885             1          McLaren
# 8886             1          McLaren
#
# [8887 rows x 26 columns]

# %%
raceResults = pd.merge(newResults,newPitStops.groupby(by=['raceId','raceName','constructorName','driverId','driverName']).sum(),left_on=['raceId','driverId'],right_on=['raceId','driverId'],how='left')
raceResults['pitPercentage'] = raceResults['milliseconds_y']/raceResults['milliseconds_x']*100
raceResults
# Out:
#        raceId  driverId  constructorId_x  number_x  grid  position  \
# 0          18         1                1      22.0     1       1.0
# 1          18         2                2       3.0     5       2.0
# 2          18         3                3       7.0     7       3.0
# 3          18         4                4       5.0    11       4.0
# 4          18         5                1      23.0     3       5.0
# ...       ...       ...              ...       ...   ...       ...
# 25415    1074       849                3       6.0    20      16.0
# 25416    1074       807              117      27.0    17      17.0
# 25417    1074       815                9      11.0     4      18.0
# 25418    1074       830                9       1.0     2      19.0
# 25419    1074       842              213      10.0    10       NaN
#
#       positionText  positionOrder  points  laps  ... milliseconds_y  \
# 0                1              1    10.0    58  ...            NaN
# 1                2              2     8.0    58  ...            NaN
# 2                3              3     6.0    58  ...            NaN
# 3                4              4     5.0    58  ...            NaN
# 4                5              5     4.0    58  ...            NaN
# ...            ...            ...     ...   ...  ...            ...
# 25415           16             16     0.0    57  ...        73893.0
# 25416           17             17     0.0    57  ...        79825.0
# 25417           18             18     0.0    56  ...        74166.0
# 25418           19             19     0.0    54  ...        74236.0
# 25419            R             20     0.0    44  ...        50450.0
#
#        seconds_y  year_y  round_y circuitId_y    lat_y     lng_y  alt_y  \
# 0            NaN     NaN      NaN         NaN      NaN       NaN    NaN
# 1            NaN     NaN      NaN         NaN      NaN       NaN    NaN
# 2            NaN     NaN      NaN         NaN      NaN       NaN    NaN
# 3            NaN     NaN      NaN         NaN      NaN       NaN    NaN
# 4            NaN     NaN      NaN         NaN      NaN       NaN    NaN
# ...          ...     ...      ...         ...      ...       ...    ...
# 25415     73.893  6066.0      3.0         9.0  78.0975  151.5318   21.0
# 25416     79.825  6066.0      3.0         9.0  78.0975  151.5318   21.0
# 25417     74.166  6066.0      3.0         9.0  78.0975  151.5318   21.0
# 25418     74.236  6066.0      3.0         9.0  78.0975  151.5318   21.0
# 25419     50.450  4044.0      2.0         6.0  52.0650  101.0212   14.0
#
#        constructorId_y  pitPercentage
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# ...                ...            ...
# 25415              9.0       1.249168
# 25416            351.0       1.348985
# 25417             27.0            NaN
# 25418             27.0            NaN
# 25419            426.0            NaN
#
# [25420 rows x 58 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## How did pit stop durations change over time?
#
# Main observations
# * Average pit times had a meaningful increase from 2013 to 2014
# * Average pit times have been fairly stable from 2014 onwards
# * Majority of pit times are clustered around 20-35s
# * Pit durations appear to have more variance in the recent years

# %%
fig = px.line(newPitStops[newPitStops['seconds']<50].groupby(by=['year','constructorName']).mean().reset_index(),
                 x='year',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Average Pit Stop Durations by Constructor',
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="86cfe9ca-073d-42d8-8f35-ee40b2157425" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86cfe9ca-073d-42d8-8f35-ee40b2157425")) {                    Plotly.newPlot(                        "86cfe9ca-073d-42d8-8f35-ee40b2157425",                        [{"hovertemplate":"constructorName=Ferrari<br>year=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Ferrari","line":{"color":"#ED1C24","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ferrari","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[22.947407407407407,22.243654320987655,22.56878021978022,24.355449999999998,24.670236111111112,23.90220253164557,23.073140625,24.722641509433963,24.616410958904112,25.34122641509434,24.301857142857145,24.590500000000002],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Force India<br>year=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Force India","line":{"color":"#FF80C7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Force India","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[23.236979381443298,22.69344155844156,23.882253521126763,24.79558208955224,25.316300000000002,24.00089024390244,24.14044155844156,25.17796153846154],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=HRT<br>year=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"HRT","line":{"color":"#b2945e","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"HRT","orientation":"v","showlegend":true,"x":[2011,2012],"xaxis":"x","y":[26.661399999999997,25.109176470588235],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Lotus<br>year=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Lotus","line":{"color":"#FFB800","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Lotus","orientation":"v","showlegend":true,"x":[2011],"xaxis":"x","y":[24.119928571428574],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=McLaren<br>year=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"McLaren","line":{"color":"#F58020","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"McLaren","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[22.582109090909093,22.594636363636365,22.994317073170734,24.454974999999997,24.665944444444445,23.968333333333334,24.08065573770492,24.803625,25.087592592592593,25.35167857142857,24.526999999999997,25.308166666666665],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Mercedes<br>year=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Mercedes","line":{"color":"#6CD3BF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mercedes","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[22.625193877551023,22.462075000000002,22.642483516483516,24.296972972972974,23.811493333333335,23.7502987012987,23.461333333333336,23.672111111111114,23.939985074626865,24.707016393442622,24.118133333333333,25.562],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Red Bull<br>year=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Red Bull","line":{"color":"#1E5BC6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Red Bull","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[22.426548076923076,22.146623529411766,22.52349438202247,24.066038961038963,24.776136986301367,24.529214285714286,23.603339285714288,23.778391304347828,23.97193846153846,24.52821818181818,23.978025641025642,24.73366666666666 ...

# %%
fig = px.scatter(newPitStops[newPitStops['seconds']<50],
                 x='date',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Pit Stop Durations over Time by Constructor',
)
fig.show()
# Out:
# <div>                            <div id="4e24e7bf-e6a4-4cb4-a074-fa4cae6a7b19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e24e7bf-e6a4-4cb4-a074-fa4cae6a7b19")) {                    Plotly.newPlot(                        "4e24e7bf-e6a4-4cb4-a074-fa4cae6a7b19",                        [{"hovertemplate":"constructorName=Toro Rosso<br>date=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Toro Rosso","marker":{"color":"#0000FF","symbol":"circle"},"mode":"markers","name":"Toro Rosso","showlegend":true,"x":["2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-11-13T00:00:00","2011-11-13T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-09T00:00:00","2012-09-23T00:00:00","2012-09-23T00:00:00","2012-09-23T00:00:00","2012-09-23 ...

# %%
fig = px.box(newPitStops[newPitStops['seconds']<50],
                 x='date',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Pit Stop Durations over Time by Constructor',
)
fig.show()
# Out:
# <div>                            <div id="629b35cd-c4e3-4960-9810-4fecfea6eb50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("629b35cd-c4e3-4960-9810-4fecfea6eb50")) {                    Plotly.newPlot(                        "629b35cd-c4e3-4960-9810-4fecfea6eb50",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=Toro Rosso<br>date=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Toro Rosso","marker":{"color":"#0000FF"},"name":"Toro Rosso","notched":false,"offsetgroup":"Toro Rosso","orientation":"v","showlegend":true,"x":["2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-11-13T00:00:00","2011-11-13T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-09T00:00:00","2012-09-23T00:00:00","2012 ...

# %% [markdown]
# ## Is there a relationship between pit stop durations and constructors?
#
# Main observations:
# * Constructors on average are fairly similar in pit durations
# * No significant performance discrepancy. Minor performance variations.

# %%
fig = px.box(newPitStops[newPitStops['seconds']<50].groupby(by=['raceId','raceName','date','constructorName']).mean().reset_index().sort_values(by='seconds',ascending=True),
                 x='constructorName',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Pit Stop Durations by Constructor from 2011 to date',
)
fig.show()
# Out:
# <div>                            <div id="ca9a5cf0-5fdb-4912-a964-e6cb03a12e43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca9a5cf0-5fdb-4912-a964-e6cb03a12e43")) {                    Plotly.newPlot(                        "ca9a5cf0-5fdb-4912-a964-e6cb03a12e43",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Aston Martin","marker":{"color":"#2D826D"},"name":"Aston Martin","notched":false,"offsetgroup":"Aston Martin","orientation":"v","showlegend":true,"x":["Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin"],"x0":" ","xaxis":"x","y":[17.393,18.911333333333335,20.61785714285714,21.197499999999998,21.241,22.05666666666667,22.061999999999998,23.372500000000002,23.9215,23.973,24.027,25.011666666666667,25.310000000000002,25.941499999999998,26.26,27.165,27.507666666666665,28.179000000000002,31.0325,31.792499999999997,33.462,33.68375],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Ferrari","marker":{"color":"#ED1C24"},"name":"Ferrari","notched":false,"offsetgroup":"Ferrari","orientation":"v","showlegend":true,"x":["Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari"],"x0":" ","xaxis":"x","y":[17.527749999999997,19.255125,19.331714285714288,19.430666666666667,19.475 ...

# %%
year = 2021
fig = px.box(newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)].groupby(by=['raceId','raceName','date','constructorName']).mean().reset_index().sort_values(by='seconds',ascending=True),
                 x='constructorName',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text=f'Pit Stop Durations by Constructor for {year} Season',
)
fig.show()
# Out:
# <div>                            <div id="d15b7001-a828-4d03-8b76-b75bef558f61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d15b7001-a828-4d03-8b76-b75bef558f61")) {                    Plotly.newPlot(                        "d15b7001-a828-4d03-8b76-b75bef558f61",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Aston Martin","marker":{"color":"#2D826D"},"name":"Aston Martin","notched":false,"offsetgroup":"Aston Martin","orientation":"v","showlegend":true,"x":["Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin","Aston Martin"],"x0":" ","xaxis":"x","y":[17.393,18.911333333333335,20.61785714285714,21.197499999999998,21.241,22.05666666666667,22.061999999999998,23.372500000000002,23.9215,23.973,24.027,25.011666666666667,25.310000000000002,25.941499999999998,27.165,27.507666666666665,28.179000000000002,31.0325,31.792499999999997,33.462,33.68375],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Ferrari","marker":{"color":"#ED1C24"},"name":"Ferrari","notched":false,"offsetgroup":"Ferrari","orientation":"v","showlegend":true,"x":["Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari","Ferrari"],"x0":" ","xaxis":"x","y":[17.527749999999997,19.9085,20.531,20.543,21.287,21.885,21.948999999999998,22.058,23.52616666666667,23.845333333333333,24.15,24.42,24.44875,24.524,25.719,25.9995,30.899999999999995,30.929000000000002,31.472250000000003,32.3685,32.971000000000004],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"AlphaTauri","marker":{"color":"#4E7C9B"},"name":"AlphaTauri","notched":false,"offsetgroup":"AlphaTauri","orientation":"v","showlegend":true,"x":["AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri","AlphaTauri"],"x0":" ","xaxis":"x","y":[17.60925,19.506500000000003,21.234,22.10425,22.549,22.79075,22.836111111111112,23.47566666666667,23.691999999999997,24.429000000000002,26.018,26.319499999999998,27.0535,27.4024,27.874,28.66633333333333,29.047199999999997,30.5035,30.6666,31.346999999999998],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"McLaren","marker":{"color":"#F58020"},"name":"McLaren","notched":false,"offsetgroup":"McLaren","orientation":"v","showlegend":true,"x":["McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren","McLaren"],"x0":" ","xaxis":"x","y":[17.86875,19.946,20.87625,20.973,21.551000000000002,21.764499999999998,22.12475,23.133499999999998,23.8125,23.978166666666667,23.990000000000002,24.2945,24.53625,24.9705,25.810999999999996,27.825,30.241,30.261499999999998,31.46066666666667,31.78175,32.497],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Alfa Romeo","marker":{"color":"#B12039"},"name":"Alfa R ...

# %% [markdown]
# ## Is there a relationship between pit stop durations and race circuit?
#
# Main Observations:
# * Race circuits appear to have a more significant impact on overall pit duration
# * Race circuits appear to have an impact on total pit time over the course of the race
# * Some circuits have larger variances, but on average the variance from track to track appear to be fairly consistent

# %%
fig = px.box(newPitStops[newPitStops['seconds']<50].groupby(by=['raceId','raceName','circuitName']).mean().reset_index().sort_values(by='seconds',ascending=True),
                 x='circuitName',
                 y='seconds',
                )
fig.update_layout(
    title_text='Pit Stop Durations by Race Circuit',
)
fig.show()
# Out:
# <div>                            <div id="f481055e-db56-468d-aaea-65a9c137dcdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f481055e-db56-468d-aaea-65a9c137dcdf")) {                    Plotly.newPlot(                        "f481055e-db56-468d-aaea-65a9c137dcdf",                        [{"alignmentgroup":"True","hovertemplate":"circuitName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Baku City Circuit","Hockenheimring","Hungaroring","Autódromo José Carlos Pace","Hockenheimring","Circuit Park Zandvoort","Red Bull Ring","Hockenheimring","Circuit de Barcelona-Catalunya","Shanghai International Circuit","Baku City Circuit","Baku City Circuit","Hungaroring","Circuit de Barcelona-Catalunya","Red Bull Ring","Hockenheimring","Yas Marina Circuit","Shanghai International Circuit","Korean International Circuit","Autódromo José Carlos Pace","Nürburgring","Circuit Gilles Villeneuve","Hockenheimring","Circuit de Barcelona-Catalunya","Baku City Circuit","Nürburgring","Autódromo José Carlos Pace","Valencia Street Circuit","Yas Marina Circuit","Circuit Gilles Villeneuve","Korean International Circuit","Red Bull Ring","Circuit de Spa-Francorchamps","Yas Marina Circuit","Hungaroring","Red Bull Ring","Shanghai International Circuit","Suzuka Circuit","Hungaroring","Valencia Street Circuit","Hungaroring","Yas Marina Circuit","Yas Marina Circuit","Autodromo Internazionale del Mugello","Shanghai International Circuit","Albert Park Grand Prix Circuit","Circuit de Barcelona-Catalunya","Suzuka Circuit","Yas Marina Circuit","Circuit de Spa-Francorchamps","Red Bull Ring","Yas Marina Circuit","Hungaroring","Circuit of the Americas","Istanbul Park","Autodromo Nazionale di Monza","Red Bull Ring","Circuit de Barcelona-Catalunya","Yas Marina Circuit","Buddh International Circuit","Circuit de Spa-Francorchamps","Hungaroring","Albert Park Grand Prix Circuit","Yas Marina Circuit","Circuit de Barcelona-Catalunya","Red Bull Ring","Bahrain International Circuit","Yas Marina Circuit","Baku City Circuit","Circuit de Barcelona-Catalunya","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Circuit de Barcelona-Catalunya","Autódromo Hermanos Rodríguez","Shanghai International Circuit","Autódromo Hermanos Rodríguez","Hungaroring","Circuit de Barcelona-Catalunya","Circuit de Spa-Francorchamps","Yas Marina Circuit","Suzuka Circuit","Jeddah Corniche Circuit","Bahrain International Circuit","Circuit de Barcelona-Catalunya","Autódromo José Carlos Pace","Autodromo Nazionale di Monza","Red Bull Ring","Nürburgring","Circuit de Spa-Francorchamps","Shanghai International Circuit","Shanghai International Circuit","Suzuka Circuit","Autódromo Hermanos Rodríguez","Autódromo Hermanos Rodríguez","Albert Park Grand Prix Circuit","Suzuka Circuit","Autódromo José Carlos Pace","Red Bull Ring","Autódromo Internacional do Algarve","Autódromo José Carlos Pace","Circuit de Spa-Francorchamps","Buddh International Circuit","Hungaroring","Autódromo Hermanos Rodríguez","Circuit de Barcelona-Catalunya","Albert Park Grand Prix Circuit","Circuit Gilles Villeneuve","Suzuka Circuit","Circuit de Spa-Francorchamps","Sepang International Circuit","Autódromo Hermanos Rodríguez","Hungaroring","Albert Park Grand Prix Circuit","Circuit de Spa-Francorchamps","Circuit de Spa-Francorchamps","Shanghai International Circuit","Korean International Circuit","Circuit de Monaco","Autódromo José Carlos Pace","Circuit de Spa-Francorchamps","Circuit Gilles Villeneuve","Red Bull Ring","Albert Park Grand Prix Circuit","Autódromo José Carlos Pace","Autódromo José Carlos Pace","Sepang International Circuit","Sepang International Circuit","Circuit Gille ...

# %%
fig = px.scatter(newPitStops[newPitStops['seconds']<50].groupby(by=['circuitName']).mean().reset_index().sort_values(by='seconds',ascending=True),
                 x='circuitName',
                 y='seconds',
                )
fig.update_layout(
    title_text='Average Race Pit Stop Durations by Circuit',
)
fig.show()
# Out:
# <div>                            <div id="d4e41b7d-f85f-4c66-9b8a-70924cf683bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4e41b7d-f85f-4c66-9b8a-70924cf683bb")) {                    Plotly.newPlot(                        "d4e41b7d-f85f-4c66-9b8a-70924cf683bb",                        [{"hovertemplate":"circuitName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Circuit Park Zandvoort","Hockenheimring","Baku City Circuit","Valencia Street Circuit","Nürburgring","Red Bull Ring","Circuit de Barcelona-Catalunya","Autodromo Internazionale del Mugello","Yas Marina Circuit","Korean International Circuit","Hungaroring","Shanghai International Circuit","Autódromo José Carlos Pace","Circuit de Spa-Francorchamps","Jeddah Corniche Circuit","Istanbul Park","Autódromo Hermanos Rodríguez","Albert Park Grand Prix Circuit","Suzuka Circuit","Circuit Gilles Villeneuve","Buddh International Circuit","Autodromo Nazionale di Monza","Autódromo Internacional do Algarve","Bahrain International Circuit","Circuit of the Americas","Sepang International Circuit","Losail International Circuit","Circuit de Monaco","Silverstone Circuit","Circuit Paul Ricard","Marina Bay Street Circuit","Sochi Autodrom","Autodromo Enzo e Dino Ferrari"],"xaxis":"x","y":[20.395931034482757,20.650318493150685,20.85652222222222,21.969491228070176,21.987115942028986,22.082,22.19424574669187,22.284975609756096,22.34076,22.436956834532374,22.488095684803003,22.550879569892473,22.85654913294798,23.31815027322404,23.35258333333333,23.475753623188407,23.540491124260353,23.663575539568345,23.704728,23.78863961038961,23.94470588235294,25.144073426573428,25.186317647058825,25.197704545454545,25.211766666666666,25.38995430107527,26.418166666666664,26.48077966101695,28.62332779097387,29.467846153846153,30.25682838983051,31.045953608247423,31.846844827586207],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %%
fig = px.box(newPitStops[newPitStops['seconds']<50].groupby(by=['raceId','raceName','circuitName','constructorName']).mean().reset_index().sort_values(by='seconds',ascending=True),
                 x='circuitName',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Average Race Pit Stop Durations by Race Circuit',
)
fig.show()
# Out:
# <div>                            <div id="cdcd4634-507d-4570-bb79-da85ead1cafe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdcd4634-507d-4570-bb79-da85ead1cafe")) {                    Plotly.newPlot(                        "cdcd4634-507d-4570-bb79-da85ead1cafe",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=Aston Martin<br>circuitName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Aston Martin","marker":{"color":"#2D826D"},"name":"Aston Martin","notched":false,"offsetgroup":"Aston Martin","orientation":"v","showlegend":true,"x":["Baku City Circuit","Circuit Park Zandvoort","Autódromo José Carlos Pace","Red Bull Ring","Red Bull Ring","Yas Marina Circuit","Circuit de Barcelona-Catalunya","Autódromo Internacional do Algarve","Circuit de Monaco","Autódromo Hermanos Rodríguez","Circuit of the Americas","Bahrain International Circuit","Autodromo Nazionale di Monza","Losail International Circuit","Bahrain International Circuit","Jeddah Corniche Circuit","Istanbul Park","Silverstone Circuit","Circuit Paul Ricard","Hungaroring","Autodromo Enzo e Dino Ferrari","Sochi Autodrom"],"x0":" ","xaxis":"x","y":[17.393,18.911333333333335,20.61785714285714,21.197499999999998,21.241,22.05666666666667,22.061999999999998,23.372500000000002,23.9215,23.973,24.027,25.011666666666667,25.310000000000002,25.941499999999998,26.26,27.165,27.507666666666665,28.179000000000002,31.0325,31.792499999999997,33.462,33.68375],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"constructorName=Ferrari<br>circuitName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"Ferrari","marker":{"color":"#ED1C24"},"name":"Ferrari","notched":false,"offsetgroup":"Ferrari","orientation":"v","showlegend":true,"x":["Baku City Circuit","Circuit de Barcelona-Catalunya","Circuit de Barcelona-Catalunya","Hockenheimring","Hockenheimring","Hockenheimring","Yas Marina Circuit","Hungaroring","Autódromo José Carlos Pace","Baku City Circuit","Hungaroring","Nürburgring","Hockenheimring","Circuit Park Zandvoort","Shanghai International Circuit","Baku City Circuit","Shanghai International Circuit","Shanghai International Circuit","Korean International Circuit","Nürburgring","Circuit Gilles Villeneuve","Baku City Circuit","Yas Marina Circuit","Red Bull Ring","Jeddah Corniche Circuit","Autódromo José Carlos Pace","Circuit de Spa-Francorchamps","Hockenheimring","Suzuka Circuit","Buddh International Circuit","Circuit de Barcelona-Catalunya","Autódromo José Carlos Pace","Circuit Gilles Villeneuve","Suzuka Circuit","Red Bull Ring","Red Bull Ring","Yas Marina Circuit","Valencia Street Circuit","Red Bull Ring","Circuit de Spa-Francorchamps","Autódromo José Carlos Pace","Korean International Circuit","Buddh International Circuit","Albert Park Grand Prix Circuit","Shanghai International Circuit","Sepang International Circuit","Albert Park Grand Prix Circuit","Hungaroring","Yas Marina Circuit","Red Bull Ring","Hungaroring","Suzuka Circuit","Autodromo Nazionale di Monza","Yas Marina Circuit","Circuit de Barcelona-Catalunya","Yas Marina Circuit","Yas Marina Circuit","Hungaroring","Circuit de Barcelona-Catalunya","Albert Park Grand Prix Circuit","Circuit de Barcelona-Catalunya","Circuit de Barcelona-Catalunya","Autódromo Hermanos Rodríguez","Circuit de Barcelona-Catalunya","Yas Marina Circuit","Hungaroring","Autodromo Nazionale di Monza","Albert Park Grand Prix Circuit","Autódromo Hermanos Rodríguez","Albert Park Grand Prix Circuit","Hungaroring","Autódromo José Carlos Pace","Circuit de Barcelona-Catalunya","Bahrain International Circuit","Istanbul Park","Autódromo Hermanos Rodríguez","Korean International Circuit","Shanghai International Circuit","Yas Marina Circuit","Circuit de Spa-Francorchamps","Yas ...

# %% [markdown]
# ## Total Time in the Pit Lane

# %%
newPitStops[newPitStops['seconds']<50].groupby(by=['raceId','circuitName','driverId']).sum().groupby(by=['raceId','circuitName']).mean()
# Out:
#                                             stop        lap  milliseconds  \
# raceId circuitName
# 841    Albert Park Grand Prix Circuit   3.666667  51.047619  52163.190476
# 842    Sepang International Circuit     5.272727  68.818182  65528.545455
# 843    Shanghai International Circuit   4.375000  62.625000  53889.833333
# 844    Istanbul Park                    8.217391  96.565217  79556.695652
# 845    Circuit de Barcelona-Catalunya   6.958333  91.416667  69196.041667
# ...                                          ...        ...           ...
# 1070   Autódromo Hermanos Rodríguez     1.944444  43.611111  33364.055556
# 1071   Autódromo José Carlos Pace      10.000000  77.850000  83650.900000
# 1072   Jeddah Corniche Circuit          1.727273  16.454545  25475.545455
# 1073   Yas Marina Circuit               2.333333  50.055556  35141.000000
# 1074   Bahrain International Circuit    5.700000  87.900000  73595.050000
#
#                                          seconds         year      round  \
# raceId circuitName
# 841    Albert Park Grand Prix Circuit  52.163190  4309.285714   2.142857
# 842    Sepang International Circuit    65.528545  5393.136364   5.363636
# 843    Shanghai International Circuit  53.889833  4859.916667   7.250000
# 844    Istanbul Park                   79.556696  7082.217391  14.086957
# 845    Circuit de Barcelona-Catalunya  69.196042  6451.958333  16.041667
# ...                                          ...          ...        ...
# 1070   Autódromo Hermanos Rodríguez    33.364056  2806.944444  25.000000
# 1071   Autódromo José Carlos Pace      83.650900  7982.950000  75.050000
# 1072   Jeddah Corniche Circuit         25.475545  2204.727273  22.909091
# 1073   Yas Marina Circuit              35.141000  3256.055556  35.444444
# 1074   Bahrain International Circuit   73.595050  5863.800000   2.900000
#
#                                        circuitId         lat         lng  \
# raceId circuitName
# 841    Albert Park Grand Prix Circuit   2.142857  -81.106500  310.645714
# 842    Sepang International Circuit     5.363636    7.404044  272.842818
# 843    Shanghai International Circuit  41.083333   75.735675  292.948333
# 844    Istanbul Park                   17.608696  144.221204  103.556739
# 845    Circuit de Barcelona-Catalunya  12.833333  133.370417    7.254395
# ...                                          ...         ...         ...
# 1070   Autódromo Hermanos Rodríguez    44.444444   26.950278 -137.625972
# 1071   Autódromo José Carlos Pace      71.100000  -93.629220 -184.463815
# 1072   Jeddah Corniche Circuit         84.000000   23.598436   42.659345
# 1073   Yas Marina Circuit              38.666667   39.419378   87.971661
# 1074   Bahrain International Circuit    8.700000   75.494250  146.480740
#
#                                                alt  constructorId
# raceId circuitName
# 841    Albert Park Grand Prix Circuit    21.428571      82.380952
# 842    Sepang International Circuit      48.272727     128.590909
# 843    Shanghai International Circuit    12.083333     139.916667
# 844    Istanbul Park                    457.826087     173.217391
# 845    Circuit de Barcelona-Catalunya   349.708333     167.583333
# ...                                            ...            ...
# 1070   Autódromo Hermanos Rodríguez    3093.055556     122.833333
# 1071   Autódromo José Carlos Pace      3100.750000     365.850000
# 1072   Jeddah Corniche Circuit           16.363636      99.363636
# 1073   Yas Marina Circuit                 4.833333     138.555556
# 1074   Bahrain International Circuit     20.300000     265.350000
#
# [218 rows x 11 columns]

# %%
fig = px.box(newPitStops[newPitStops['seconds']<50].groupby(by=['raceId','circuitName','driverId']).sum().reset_index().sort_values(by='seconds',ascending=True),
                 x='circuitName',
                 y='seconds',
                )
fig.update_layout(
    title_text='Total Time Spent in Pit Lane by Circuit',
)
fig.show()
# Out:
# <div>                            <div id="28b460b5-0ed7-40aa-acda-2766a3e17907" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28b460b5-0ed7-40aa-acda-2766a3e17907")) {                    Plotly.newPlot(                        "28b460b5-0ed7-40aa-acda-2766a3e17907",                        [{"alignmentgroup":"True","hovertemplate":"circuitName=%{x}<br>seconds=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Autodromo Internazionale del Mugello","Circuit Gilles Villeneuve","Hockenheimring","Hockenheimring","Hockenheimring","Hockenheimring","Circuit Park Zandvoort","Yas Marina Circuit","Circuit Park Zandvoort","Circuit Park Zandvoort","Yas Marina Circuit","Circuit Park Zandvoort","Circuit Park Zandvoort","Yas Marina Circuit","Circuit Park Zandvoort","Yas Marina Circuit","Hockenheimring","Yas Marina Circuit","Circuit de Spa-Francorchamps","Circuit Park Zandvoort","Baku City Circuit","Baku City Circuit","Baku City Circuit","Baku City Circuit","Circuit Park Zandvoort","Yas Marina Circuit","Baku City Circuit","Baku City Circuit","Baku City Circuit","Circuit Park Zandvoort","Baku City Circuit","Baku City Circuit","Baku City Circuit","Circuit de Barcelona-Catalunya","Baku City Circuit","Circuit Gilles Villeneuve","Yas Marina Circuit","Korean International Circuit","Yas Marina Circuit","Valencia Street Circuit","Circuit Park Zandvoort","Baku City Circuit","Baku City Circuit","Circuit Park Zandvoort","Jeddah Corniche Circuit","Jeddah Corniche Circuit","Jeddah Corniche Circuit","Baku City Circuit","Baku City Circuit","Circuit Park Zandvoort","Buddh International Circuit","Jeddah Corniche Circuit","Baku City Circuit","Yas Marina Circuit","Autodromo Nazionale di Monza","Red Bull Ring","Yas Marina Circuit","Baku City Circuit","Baku City Circuit","Buddh International Circuit","Buddh International Circuit","Circuit de Spa-Francorchamps","Circuit of the Americas","Buddh International Circuit","Baku City Circuit","Circuit of the Americas","Baku City Circuit","Red Bull Ring","Red Bull Ring","Baku City Circuit","Nürburgring","Albert Park Grand Prix Circuit","Baku City Circuit","Jeddah Corniche Circuit","Buddh International Circuit","Red Bull Ring","Baku City Circuit","Yas Marina Circuit","Yas Marina Circuit","Yas Marina Circuit","Circuit Gilles Villeneuve","Red Bull Ring","Buddh International Circuit","Red Bull Ring","Red Bull Ring","Circuit Gilles Villeneuve","Korean International Circuit","Red Bull Ring","Yas Marina Circuit","Red Bull Ring","Red Bull Ring","Albert Park Grand Prix Circuit","Circuit of the Americas","Red Bull Ring","Red Bull Ring","Yas Marina Circuit","Yas Marina Circuit","Yas Marina Circuit","Hockenheimring","Red Bull Ring","Red Bull Ring","Red Bull Ring","Red Bull Ring","Red Bull Ring","Yas Marina Circuit","Yas Marina Circuit","Red Bull Ring","Yas Marina Circuit","Albert Park Grand Prix Circuit","Suzuka Circuit","Yas Marina Circuit","Yas Marina Circuit","Yas Marina Circuit","Hungaroring","Valencia Street Circuit","Yas Marina Circuit","Red Bull Ring","Hungaroring","Hungaroring","Hungaroring","Circuit of the Americas","Circuit de Barcelona-Catalunya","Red Bull Ring","Hungaroring","Baku City Circuit","Circuit Gilles Villeneuve","Red Bull Ring","Albert Park Grand Prix Circuit","Circuit Gilles Villeneuve","Baku City Circuit","Buddh International Circuit","Circuit Gilles Villeneuve","Red Bull Ring","Red Bull Ring","Albert Park Grand Prix Circuit","Red Bull Ring","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Circuit of the Americas","Yas Marina Circuit","Circuit Gilles Villeneuve","Red Bull Ring","Korean International Circuit","Yas Marina Circuit","Yas Marina Circuit","Hungaror ...

# %% [markdown]
# ## Percentage of race spent in the pit lane
#
# Main Observations:
# * Findings from pit percentage unsurprisingly are very similar to the average pit time with its correlation to circuit
# * There doesn't appear to be much of a correlation between percentage of time in the pit and the race outcome
# * Pit percentage does not appear to yield any interesting insights

# %%
fig = px.box(raceResults[raceResults['pitPercentage']<10].groupby(by=['raceId','raceName','circuitName','constructorName']).mean().reset_index().sort_values(by='pitPercentage',ascending=True),
                 x='circuitName',
                 y='pitPercentage',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Average Race Percentage in the Pit Lane by Race Circuit',
)
fig.add_hline(y=raceResults[raceResults['pitPercentage']<10].mean()['pitPercentage'],line_dash='dash',annotation_text=f"Average pit percentage: {raceResults[raceResults['pitPercentage']<10]['pitPercentage'].mean():.2f}%")
fig.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
#
# DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# <div>                            <div id="72a66e9e-6f6a-465a-b0b4-d3f768f39690" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72a66e9e-6f6a-465a-b0b4-d3f768f39690")) {                    Plotly.newPlot(                        "72a66e9e-6f6a-465a-b0b4-d3f768f39690",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=Red Bull<br>circuitName=%{x}<br>pitPercentage=%{y}<extra></extra>","legendgroup":"Red Bull","marker":{"color":"#1E5BC6"},"name":"Red Bull","notched":false,"offsetgroup":"Red Bull","orientation":"v","showlegend":true,"x":["Circuit de Monaco","Yas Marina Circuit","Hungaroring","Circuit of the Americas","Yas Marina Circuit","Autódromo Hermanos Rodríguez","Yas Marina Circuit","Circuit de Barcelona-Catalunya","Yas Marina Circuit","Buddh International Circuit","Baku City Circuit","Autódromo Hermanos Rodríguez","Circuit de Monaco","Albert Park Grand Prix Circuit","Circuit de Monaco","Circuit of the Americas","Marina Bay Street Circuit","Circuit de Monaco","Circuit de Monaco","Istanbul Park","Albert Park Grand Prix Circuit","Circuit of the Americas","Circuit Gilles Villeneuve","Red Bull Ring","Red Bull Ring","Circuit Gilles Villeneuve","Circuit Gilles Villeneuve","Marina Bay Street Circuit","Albert Park Grand Prix Circuit","Circuit de Spa-Francorchamps","Suzuka Circuit","Red Bull Ring","Sepang International Circuit","Autódromo José Carlos Pace","Circuit Paul Ricard","Circuit de Spa-Francorchamps","Silverstone Circuit","Autodromo Nazionale di Monza","Autódromo Internacional do Algarve","Circuit Gilles Villeneuve","Suzuka Circuit","Autodromo Nazionale di Monza","Autodromo Nazionale di Monza","Sochi Autodrom","Autodromo Nazionale di Monza","Autodromo Nazionale di Monza","Sochi Autodrom","Sochi Autodrom","Autódromo Hermanos Rodríguez","Yas Marina Circuit","Sochi Autodrom","Hungaroring","Circuit de Monaco","Circuit de Spa-Francorchamps","Circuit de Monaco","Autódromo Hermanos Rodríguez","Circuit Paul Ricard","Circuit de Monaco","Circuit de Monaco","Sochi Autodrom","Red Bull Ring","Red Bull Ring","Hockenheimring","Valencia Street Circuit","Red Bull Ring","Korean International Circuit","Korean International Circuit","Circuit Park Zandvoort","Yas Marina Circuit","Hungaroring","Autódromo Hermanos Rodríguez","Yas Marina Circuit","Baku City Circuit","Yas Marina Circuit","Yas Marina Circuit","Korean International Circuit","Autódromo Hermanos Rodríguez","Hungaroring","Circuit de Barcelona-Catalunya","Hungaroring","Shanghai International Circuit","Circuit Gilles Villeneuve","Nürburgring","Circuit de Barcelona-Catalunya","Circuit Gilles Villeneuve","Circuit de Barcelona-Catalunya","Sochi Autodrom","Buddh International Circuit","Circuit de Barcelona-Catalunya","Circuit Gilles Villeneuve","Shanghai International Circuit","Shanghai International Circuit","Circuit of the Americas","Red Bull Ring","Marina Bay Street Circuit","Albert Park Grand Prix Circuit","Marina Bay Street Circuit","Hungaroring","Albert Park Grand Prix Circuit","Bahrain International Circuit","Circuit de Spa-Francorchamps","Marina Bay Street Circuit","Circuit de Monaco","Circuit Gilles Villeneuve","Circuit of the Americas","Circuit of the Americas","Silverstone Circuit","Circuit Paul Ricard","Silverstone Circuit","Bahrain International Circuit","Sepang International Circuit","Buddh International Circuit","Suzuka Circuit","Bahrain International Circuit","Circuit de Barcelona-Catalunya","Bahrain International Circuit","Shanghai International Circuit","Circuit de Spa-Francorchamps","Autodromo Nazionale di Monza","Bahrain International Circuit","Suzuka Circuit","Circuit de Spa-Francorchamps","Circuit de Spa-Francorchamps","Istanbul Park","Autodromo Nazionale di Monza","Shanghai International Circuit","Suzuka Ci ...

# %%
fig = px.scatter(raceResults[raceResults['pitPercentage']<10].groupby(by=['raceId','raceName','circuitName','constructorName']).mean().reset_index(),
                 x='pitPercentage',
                 y='positionOrder',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Average Race Percentage in the Pit Lane by Race Circuit',
)
fig.show()
# Out:
# <div>                            <div id="3b498da5-2878-4c90-8a3e-ed3c36d8eed1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b498da5-2878-4c90-8a3e-ed3c36d8eed1")) {                    Plotly.newPlot(                        "3b498da5-2878-4c90-8a3e-ed3c36d8eed1",                        [{"hovertemplate":"constructorName=Ferrari<br>pitPercentage=%{x}<br>positionOrder=%{y}<extra></extra>","legendgroup":"Ferrari","marker":{"color":"#ED1C24","symbol":"circle"},"mode":"markers","name":"Ferrari","showlegend":true,"x":[1.3318395693374443,1.4642981918858409,0.7409615000700436,1.6437618305678656,0.7292746292151268,0.6697178952531142,1.0720759440973797,1.362036416775373,1.0450534786058223,1.3418133735428577,1.0270829858015527,0.9074743217783335,1.263224073290878,1.1596631977973746,0.7313677324514665,0.7991496350358278,0.6997958803750568,0.9393995542086013,0.7748896604380432,0.8472117618982327,0.8646601995337606,1.1798304917193763,1.0011020875823626,0.39412945883202005,0.5688132162174528,0.6474232452547681,0.9848898148134673,0.883483360684162,0.6471891251928152,0.7689125432867735,0.45435117654557755,1.0303169820319178,0.7786993961598176,0.7017340908206915,0.3810567200889036,0.30572553539186714,0.3963573253724012,1.0594405878789894,1.1967509232953324,1.4519326256568532,1.0459669145470134,1.5413946457885608,1.2902075906050143,0.2950912120923653,0.7422679073395375,1.6413945567480126,0.9735250636587471,1.0654690860709093,0.895491822974283,0.5179223954364993,1.0157663411892417,0.7221261926049913,1.0333071673529604,1.1231761784503167,0.7278983688252973,0.5964287233939576,0.9642235895730101,0.8197802380020118,1.2096570650511733,1.2443624067098646,0.813029151914065,1.0669443894568056,0.4014931259510254,0.8006178014727166,0.8104517067863113,0.3878476652494804,1.013394519240206,0.6559386764270336,0.9516723982570717,0.509932857213191,1.2133922016787848,0.5843676985362247,0.7989159372696727,1.105624706328412,0.7251009783908666,0.4090048102310677,1.0311560416295742,0.7535225932413416,1.1526475293086205,0.7184154312087643,0.37324727066453633,0.8936746602033648,0.5865933556830762,1.0633080194124183,1.219594708621763,0.9007129503219998,0.5159295683308337,0.8172231079413451,0.8703914945751468,0.5004512400772119,1.1230777736579045,1.0891515914383563,0.76751098095307,1.336876339783018,1.2696722164568444,0.5451917636680047,0.9022460537148664,0.7052908574958953,0.8277183772013855,0.3663828448785085,1.169746725527917,1.0437363633783532,0.7166406836926714,1.083781081272397,1.058367049557815,1.3971061911715537,1.2591355783894427,0.8810755708187445,1.2197443558962706,0.5549227511764698,0.7433902226730111,0.43474480699029106,1.5277863378446566,0.8972795686922583,0.5689717438483282,0.7778837000847398,0.3908650592853677,0.907397243457301,0.4412687951268115,1.222251080168835,0.36942372272429436,1.217083334348886,0.5422056518965228,0.4356778113400159,0.44852053894382393,0.6334849514676042,0.657528489240661,1.4248853256884542,0.37659314538528404,0.40182955364376843,0.44411927692079234,0.39870878501576357,0.7387655477529841,0.8046296032552701,0.3897088959045245,0.4429510412282351,0.8047311923999616,0.4621818949490871,1.184449075477505,0.7132988528729108,0.5926955164106323,0.8342845792860509,0.8683520897103957,0.43341315250816065,0.564267282199316,0.4297236882863881,0.4248767936286877,0.5596497185532583,0.6477919749084504,0.378240681080595,0.42720472537394394,1.156387413898677,0.8308886422166804,0.5412661342115611,0.786859260858455,0.39418525628320805,0.44395148448430205,0.8860056712584374,0.7026305175335013,1.1616861985612534,1.6526274613736038,0.40223662611806227,0.675121143145816,0.5265024029832117,0.4114697468208525,1.0481305443401412,0.9602451008089676,0.5990030605057909,0.931821490281461,0.7947187617956606,1.1680875914103224, ...

# %% [markdown]
# ## What is a "good" pit stop?
#
# After exploring some relationships that pit stops might have with other features, the circuit has a meaningful effect to the pit times measured. To get a good reference on what a "good" pit stop is, we can take a look at the distribution of all the pit stops available.
#
# There may be some minor normalization based on the circuit to provide a more meaningful comparison with respect to a particular pit time.

# %%
fig = px.histogram(newPitStops[(newPitStops['seconds']<50)],
                 x='seconds',
                 
                )
fig.update_layout(
    title_text='Pit Stop Duration Distribution',
)
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].mean(),annotation_text=f"Average: {newPitStops[(newPitStops['seconds']<50)]['seconds'].mean():.2f}s")
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1),line_dash='dash',annotation_text=f"Top Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1):.2f}s")
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9),line_dash='dash',annotation_text=f"Bottom Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9):.2f}s")
fig.update_traces(opacity=0.9)
fig.show()
# Out:
# <div>                            <div id="54502b8a-9541-487e-a06c-1481a56936e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54502b8a-9541-487e-a06c-1481a56936e1")) {                    Plotly.newPlot(                        "54502b8a-9541-487e-a06c-1481a56936e1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[26.898,24.463,26.348,25.021,23.988,23.426,22.52,26.23,23.251,24.733,24.181,23.842,24.5,24.095,23.643,37.856,16.892,26.309,22.603,24.036,24.863,24.332,25.259,26.446,25.342,23.1,22.994,25.098,23.227,23.199,24.535,25.683,23.716,24.064,24.192,25.978,23.871,24.899,24.848,16.867,23.303,22.681,24.865,23.792,23.438,31.694,22.046,22.55,32.978,24.502,22.572,21.991,22.069,22.161,22.773,22.419,23.977,22.552,22.611,25.382,22.466,23.019,21.893,22.313,23.9,23.221,22.602,22.4,22.471,22.483,29.224,22.541,22.893,25.516,23.152,23.894,23.812,27.182,22.576,22.261,22.227,23.182,22.68,28.694,23.28,29.843,27.439,24.967,22.577,22.526,29.084,23.336,23.584,22.888,23.28,23.442,23.597,24.617,24.429,26.252,24.416,27.815,26.554,38.823,22.419,14.16,24.467,23.499,20.522,21.964,21.4,23.442,21.132,21.091,23.16,22.062,27.62,21.989,21.218,20.771,22.005,20.72,22.01,24.722,21.928,23.779,20.758,21.237,21.995,21.533,21.855,21.936,21.624,21.168,20.878,20.533,20.567,20.989,21.058,28.708,22.524,21.251,21.473,23.397,13.9,28.845,21.709,21.481,22.683,21.908,33.827,21.981,22.005,22.216,21.821,22.485,21.89,23.029,22.26,22.901,22.802,26.049,29.27,22.895,22.365,21.715,30.182,20.907,20.379,20.597,21.422,21.323,21.838,21.662,22.022,21.322,23.471,26.685,20.833,21.075,35.688,22.041,21.769,22.128,22.032,21.05,20.421,20.843,22.087,21.308,21.732,21.702,21.379,22.573,20.927,20.949,20.308,22.3,21.919,20.872,21.884,22.717,22.868,21.687,21.649,21.084,21.006,20.623,20.112,20.385,20.489,20.775,20.93,20.887,21.403,23.881,22.555,21.827,13.925,21.368,22.639,21.417,21.82,23.455,22.456,22.713,21.826,21.986,21.931,23.066,22.862,22.219,27.353,24.962,24.474,22.854,21.633,23.114,24.634,25.125,43.603,22.779,24.837,24.871,21.128,20.5,23.592,21.143,21.829,22.689,24.821,21.574,22.077,20.253,19.887,20.426,20.292,20.818,24.745,20.819,20.567,20.238,20.738,20.38,20.881,20.079,20.279,19.984,20.084,20.487,20.451,19.761,20.235,20.473,20.988,21.856,24.232,21.739,20.647,19.534,20.395,20.8,21.635,22.419,20.741,20.872,21.019,23.143,29.936,21.226,20.65,20.637,20.773,20.267,23.23,20.015,20.763,20.107,24.843,24.448,24.298,20.07,20.126,20.573,22.364,21.723,23.001,21.019,20.807,23.068,23.157,22.744,21.632,21.17,23.176,22.982,21.708,21.322,21.953,20.796,35.084,25.28,26.421,24.67,25.189,25.31,25.116,28.536,37.735,26.269,25.352,31.382,26.477,25.878,24.97,19.36,47.226,31.445,19.347,26.977,26.827,25.595,26.065,26.468,25.687,26.615,28.325,39.917,28.856,25.907,27.55,25.921,25.675,25.851,26.281,26.073,25.045,28.298,27.577,26.464,28.642,25.037,27.879,23.65,14.501,23.868,23.589,31.718,23.741,27.202,34.897,33.278,23.305,25.066,24.684,23.059,24.052,22.923,14.565,32.449,23.893,26.348,26.129,23.105,22.986,22.735,22.702,23.571,24.943,23.593,23.7,31.701,23.949,24.649,23.97,26.561,24.143,30.497,24.655,14.538,30.714,24.472,24.196,22.832,22.869,26.045,24.863,23.338,44.037,23.332,25.14,23.872,22.958,22.526,29.546,22.402,22.77,24.886,22.742,22.56,28.346,24.425,25.079,23.113,23.364,22.479,28.63,14.538,23.129,30.288,24.039,23.687,24.618,23.816,24.145,29.115,29.54,21.301,21.805,21.49,22.114,22.285,21.472,21.163,21.262,21.286,23.492,20.545,20.34,21.035,20.212,21.054,23.547,20.896,20.676,20.286,21.036,20.465,20.319,20.367,21.006,20.441,20.331,21.477,20.551,20.136,20.997,20.325,20.479,21.20 ...

# %% [markdown]
# ### Circuit Specific Benchmarks
#
# Double click on the circuit to see the circuit specific pit time distribution.

# %%
fig = px.histogram(newPitStops[(newPitStops['seconds']<50)],
                 x='seconds',
                 color='circuitName',
                )
fig.update_layout(
    title_text='Pit Stop Duration Distribution by Circuit',
    barmode='overlay',
)
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].mean(),annotation_text=f"Average: {newPitStops[(newPitStops['seconds']<50)]['seconds'].mean():.2f}s",annotation_position='top')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1),line_dash='dash',annotation_text=f"Top Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1):.2f}s",annotation_position='top left')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9),line_dash='dash',annotation_text=f"Bottom Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9):.2f}s",annotation_position='bottom right')
fig.update_traces(opacity=0.9)
fig.show()
# Out:
# <div>                            <div id="958503aa-32dd-4c2f-aa45-52606e65c0a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("958503aa-32dd-4c2f-aa45-52606e65c0a5")) {                    Plotly.newPlot(                        "958503aa-32dd-4c2f-aa45-52606e65c0a5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"circuitName=Albert Park Grand Prix Circuit<br>seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Albert Park Grand Prix Circuit","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Albert Park Grand Prix Circuit","offsetgroup":"Albert Park Grand Prix Circuit","orientation":"v","showlegend":true,"x":[26.898,24.463,26.348,25.021,23.988,23.426,22.52,26.23,23.251,24.733,24.181,23.842,24.5,24.095,23.643,37.856,16.892,26.309,22.603,24.036,24.863,24.332,25.259,26.446,25.342,23.1,22.994,25.098,23.227,23.199,24.535,25.683,23.716,24.064,24.192,25.978,23.871,24.899,24.848,16.867,23.303,22.681,24.865,23.792,23.438,24.599,23.777,30.888,32.319,23.257,24.348,22.313,22.528,22.103,23.203,23.017,22.035,21.91,25.346,24.162,24.933,24.579,23.302,22.915,24.397,24.58,28.888,23.275,22.837,24.256,24.131,23.427,23.166,22.862,23.464,24.579,24.881,23.31,23.203,23.569,26.322,25.046,25.303,48.984,17.088,23.882,22.282,23.571,21.538,24.24,21.717,21.515,22.239,22.133,22.534,22.316,22.315,23.528,23.215,24.06,36.564,30.838,22.948,21.807,22.704,21.596,24.104,23.834,23.917,21.754,21.511,21.509,23.01,23.051,23.394,23.509,21.792,21.606,21.704,22.709,22.181,23.074,24.688,23.16,23.371,23.387,22.669,23.099,22.155,22.015,21.778,22.274,23.435,24.177,23.677,22.004,21.705,22.693,22.749,17.255,22.264,32.657,23.797,25.541,22.497,22.526,22.411,22.399,24.331,23.673,22.994,22.427,23.15,22.273,22.615,22.933,22.887,21.978,25.543,21.825,23.124,22.978,30.514,23.92,23.238,24.209,23.493,23.821,22.656,22.847,34.921,23.117,24.305,22.681,23.254,22.353,27.465,22.405,22.062,22.137,21.612,22.535,22.694,22.295,22.933,22.105,23.353,23.532,26.009,27.831,22.079,22.414,22.392,22.701,21.55,26.206,23.895,22.357,16.936,21.531,22.245,21.981,21.796,23.286,23.224,21.339,24.548,22.303,29.066,22.616,21.837,22.508,21.94,22.167,24.719,21.376,31.336,22.189,22.293,22.38,39.562,22.154,28.591,22.484,23.13,23.159,21.709,22.045,21.762,21.568,21.988,21.44,22.208,22.033,25.559,24.026,22.213,22.296,21.421,21.821,22.242,22.836,20.953,21.983,23.868,21.854,23.054,22.628,22.327,22.474,21.664,25.504,21.397,21.787,21.44,22.573,32.997,22.343,21.889,33.027,23.299,21.588,23.234,21.995,22.388,21.78,21.515,29.981,21.627,22.014,21.157,22.086,21.689,21.543,22.471,27.172,22.306,21.269],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.9},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"circuitName=Sepang International Circuit<br>seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sepang International Circuit","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Sepang International Circuit","offsetgroup":"Sepang International Circuit","orientation":"v","showlegend":true,"x":[31.694,22.046,22.55,32.978,24.502,22.572,21.991,22.069,22.161,22.773,22.419,23.977,22.552,22.611,25.382,22.466,23.019,21.893,22.313,23.9,23.221,22.602,22.4,22.471,22.483,29.224,22.541,22.893,25.516,23.152,23.894,23.812,27.182,22.576,22.261,22.227,23.182,22.68,28.694,23.28,29.843,27.439,24.967,22.577,22.526,29.084,23.336,23.584,22.888,23.28,23.442,23.597,24.617,24.429,26.252,24.416,27.815,26.554,38.823,25.671,24.52,24.543,31.006,26.269,24.98,23.824,23.988,22.856,22.175,24.034,24.42,23.13,26.934,25.096,25.66,25.39,29.317,36.542,32.224,24.305,25.922,36.517,23.509,23.477,24.653,22.864,22.534,23.856,23.549,23.358,25.47,24.539,22.61,23.648,24.718,29.359,30.335,32.67,25.13,34.109,23.782,24.271,27.961,26.338,24.569,26.337,23.195,25.658,24.057,22. ...

# %% [markdown]
# # So who does it best?
#
# As far as performance is concerned, it seems like speed and consistency are the two main factors that indicate a great team. Average pit time will provide both an indication of speed and consistency as an expected performance metric. Obviously the lower average the better. Standard deviation is another aspect that we can look at to evaluate the consistency of a team's ability to perform.

# %% [markdown]
# ### Ranking on Average Pit Time

# %%
year = 2021
newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)].groupby(by='constructorName')['seconds'].describe().sort_values(by='mean')
# Out:
#                  count       mean       std     min      25%      50%  \
# constructorName
# Red Bull          78.0  23.978026  4.623024  15.277  21.3920  22.7440
# Mercedes          75.0  24.118133  4.659454  15.432  21.5555  22.6800
# Ferrari           63.0  24.301857  4.996534  15.092  21.5220  23.0640
# McLaren           66.0  24.527000  4.924235  14.994  21.4925  23.5255
# Aston Martin      66.0  24.799500  5.382271  14.945  21.4905  23.5500
# Williams          67.0  24.936910  5.009406  18.153  21.9615  23.6810
# Alpine F1 Team    61.0  24.983246  5.237372  15.432  21.4520  23.8440
# Alfa Romeo        68.0  25.003559  5.171887  14.881  21.7985  24.0195
# AlphaTauri        68.0  25.212441  5.380044  14.943  21.7500  24.3225
# Haas F1 Team      69.0  25.398290  5.636702  15.054  22.1130  24.2930
#
#                       75%     max
# constructorName
# Red Bull         25.38925  44.608
# Mercedes         25.50000  40.266
# Ferrari          26.37900  42.786
# McLaren          26.53250  38.267
# Aston Martin     26.13175  43.124
# Williams         26.50700  46.315
# Alpine F1 Team   29.11600  40.800
# Alfa Romeo       28.40050  37.190
# AlphaTauri       28.79725  40.740
# Haas F1 Team     27.18600  49.729

# %% [markdown]
# ### Ranking on Consistency

# %%
newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)].groupby(by='constructorName')['seconds'].describe().sort_values(by='std')
# Out:
#                  count       mean       std     min      25%      50%  \
# constructorName
# Red Bull          78.0  23.978026  4.623024  15.277  21.3920  22.7440
# Mercedes          75.0  24.118133  4.659454  15.432  21.5555  22.6800
# McLaren           66.0  24.527000  4.924235  14.994  21.4925  23.5255
# Ferrari           63.0  24.301857  4.996534  15.092  21.5220  23.0640
# Williams          67.0  24.936910  5.009406  18.153  21.9615  23.6810
# Alfa Romeo        68.0  25.003559  5.171887  14.881  21.7985  24.0195
# Alpine F1 Team    61.0  24.983246  5.237372  15.432  21.4520  23.8440
# AlphaTauri        68.0  25.212441  5.380044  14.943  21.7500  24.3225
# Aston Martin      66.0  24.799500  5.382271  14.945  21.4905  23.5500
# Haas F1 Team      69.0  25.398290  5.636702  15.054  22.1130  24.2930
#
#                       75%     max
# constructorName
# Red Bull         25.38925  44.608
# Mercedes         25.50000  40.266
# McLaren          26.53250  38.267
# Ferrari          26.37900  42.786
# Williams         26.50700  46.315
# Alfa Romeo       28.40050  37.190
# Alpine F1 Team   29.11600  40.800
# AlphaTauri       28.79725  40.740
# Aston Martin     26.13175  43.124
# Haas F1 Team     27.18600  49.729

# %% [markdown]
# ### Constructor Specific Performance

# %%
fig = px.histogram(newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)],
                 x='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Pit Stop Duration Distribution by Constructor',
    barmode='overlay',
)
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].mean(),annotation_text=f"Average: {newPitStops[(newPitStops['seconds']<50)]['seconds'].mean():.2f}s",annotation_position='top')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1),line_dash='dash',annotation_text=f"Top Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1):.2f}s",annotation_position='top left')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9),line_dash='dash',annotation_text=f"Bottom Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9):.2f}s",annotation_position='bottom right')

fig.update_traces(opacity=0.5)
fig.show()
# Out:
# <div>                            <div id="c45fd60d-cfc1-4c3f-8777-518be9a9d21b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c45fd60d-cfc1-4c3f-8777-518be9a9d21b")) {                    Plotly.newPlot(                        "c45fd60d-cfc1-4c3f-8777-518be9a9d21b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=Red Bull<br>seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Red Bull","marker":{"color":"#1E5BC6","pattern":{"shape":""}},"name":"Red Bull","offsetgroup":"Red Bull","orientation":"v","showlegend":true,"x":[23.993,24.105,24.191,24.767,23.848,29.809,44.608,22.718,22.104,26.743,26.319,21.89,22.1,26.607,23.565,21.592,22.382,21.345,23.746,24.548,19.769,21.874,15.277,29.803,30.123,29.682,23.477,20.961,20.936,21.09,21.236,21.735,27.892,27.848,29.082,22.569,35.245,21.047,20.848,19.287,18.555,19.142,18.578,32.456,23.906,29.578,31.017,36.026,32.313,22.442,22.463,23.727,24.052,25.018,23.604,21.908,22.114,17.916,17.807,22.722,22.766,18.308,18.136,23.165,22.656,22.916,25.3,25.175,25.465,25.419,25.42,20.71,21.152,21.871,21.453,21.471,21.413,21.385],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.5},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=AlphaTauri<br>seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"AlphaTauri","marker":{"color":"#4E7C9B","pattern":{"shape":""}},"name":"AlphaTauri","offsetgroup":"AlphaTauri","orientation":"v","showlegend":true,"x":[38.338,24.317,24.983,25.046,24.328,31.068,32.277,30.696,21.353,22.319,26.172,22.266,22.542,26.202,28.042,26.065,24.428,24.43,20.253,14.943,20.156,15.085,30.226,30.781,21.234,21.145,26.604,22.564,20.85,28.685,28.18,29.134,40.74,21.819,39.839,21.295,21.543,19.163,19.85,30.112,30.98,30.972,29.354,31.915,23.329,29.31,23.802,23.529,23.745,22.549,31.939,17.758,17.711,18.499,35.416,19.439,18.608,23.116,23.039,25.659,26.674,25.63,26.109,27.874,22.455,21.909,22.133,21.92],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.5},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=Alpine F1 Team<br>seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Alpine F1 Team","marker":{"color":"#2293D1","pattern":{"shape":""}},"name":"Alpine F1 Team","offsetgroup":"Alpine F1 Team","orientation":"v","showlegend":true,"x":[24.373,24.775,25.226,24.471,30.866,30.652,30.701,30.864,21.275,22.24,27.033,21.452,21.621,26.442,22.043,23.479,22.798,23.935,23.803,20.168,19.983,15.432,31.288,30.207,21.131,21.238,22.663,29.743,28.772,39.522,21.642,37.122,21.523,19.24,19.018,24.797,30.333,29.901,33.264,30.157,30.702,29.116,40.8,23.919,23.576,23.844,23.314,23.1,23.985,19.285,17.818,23.504,17.751,17.705,24.375,25.991,25.517,20.405,21.097,21.677,21.304],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.5},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=McLaren<br>seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"McLaren","marker":{"color":"#F58020","pattern":{"shape":""}},"name":"McLaren","offsetgroup":"McLaren","orientation":"v","showlegend":true,"x":[24.899,25.64,24.688,24.655,34.34,30.654,21.407,22.551,26.952,21.965,22.355,28.639,21.864,22.467,22.406,21.762,23.874,24.715,20.533,15.866,20.082,14.994,29.951,30.531,21.692,21.41,21.151,26.474,31.706,28.817,38.267,34.492,21.623,19.449,20.443,23.812,24.168,33.617,31.016,29.824,32.67,23.028,23.239,24.385,25.548,24.176,24.036,38.128,22.813,22.534,27.313,17.719,17.673,19.176,24.211,19.732,18.347,22.839,25.319,26.552,25.562,20.973,21.38,22.173,21.449,22.056],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.5},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=Ferrari<br>seconds=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Ferrari","marker":{"colo ...

# %% [markdown]
# # Conclusions
#
# Pit stops are cool and play an integral part of the F1 sport, but optimizing it is probably a waste of time (at least in today's state). The pit time on average accounts for less than 1% of the race time (0.83%). Your efforts are likely better spent in other areas.
#
# ### How did pit stop durations change over time?
# Average pit stops have increased since 2013 and have stayed relatively similar since then. Pit stop times have also increased in variance over the past couple years as well
#
# ### Is there a relationship between pit stop durations and constructor?
# Not meaningful. There are some differences between the constructors; however, it doesn't appear to make a significant results on the race outcome.
#
# ### Is there a relationship between pit stop durations and race circuit?
# Yes. The circuits have an impact on the overall time spent in the pit lane. Either by the number of stops, track layout, or the length of pit lane.
#
# ### What is the time spent in the pit lane as a percentage of the race?
# Average time spent in the pit lane is about
#
# ### Who is the best constructor on pit stop performance (for 2021)?
# 1. Red Bull
# 2. Mercedes
# 3. Ferrari

# %% [markdown]
# <img style="width:100%" src="https://www.wsupercars.com/thumbnails-wide/Formula-1/Red-Bull-Racing/2022-Formula1-Red-Bull-Racing-RB18-001.jpg">
